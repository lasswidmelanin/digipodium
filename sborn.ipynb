# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np

# %% [markdown]
# # Count Plot

# %%
tps=sns.load_dataset("tips")
tps
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[136], line 1
# ----> 1 tps=sns.load_dataset("tips")
#       2 tps
#
# TypeError: 'str' object is not callable

# %%
sns.countplot(x='sex',data=tps,hue='smoker',   # to plot horizontally use y='sex'
              palette='bwr', 
              saturation=2
              # color='y'
              )
plt.show()

# %%
sns.barplot(x='sex',y='size',data=tps)
plt.show()

# %% [markdown]
# # Violin Plot

# %%
tps=sns.load_dataset('tips')
tps
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.violinplot(x='day',y='total_bill',data=tps)
plt.show()

# %%
sns.violinplot(x='day',y='total_bill',data=tps,hue='time')
plt.show()

# %%
sns.violinplot(x='day',y='total_bill',data=tps,linewidth=1.5,palette='Dark2')
plt.show()

# %%
sns.violinplot(x='time',y='total_bill',data=tps,order=['Dinner','Lunch'],
               inner='quart', # 'box'  'quartile'  'point' 'stick' 'None'
               saturation=0.4,color='y')
plt.show()

# %%
sns.violinplot(x='day',y='total_bill',data=tps,hue='sex',split=True)
plt.show()

# %%
sns.violinplot(x=tps['total_bill'])
plt.show()

# %%
sns.violinplot(y=tps['total_bill'])
plt.show()

# %% [markdown]
# # Pair plot

# %%
tp=sns.load_dataset('tips')
tp
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.pairplot(tp,vars=['total_bill','tip'],hue='sex',
             hue_order=['Female','Male'],
             #palette='BuGn'
             )
plt.show()
# Out:
# c:\Users\Naincy\miniconda3\lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.pairplot(tp,hue='sex',
             hue_order=['Female','Male'],
             y_vars=['total_bill','tip'], # x_vars=['total_bill','tip']
             )
plt.show()
# Out:
# c:\Users\Naincy\miniconda3\lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.pairplot(tp,hue='sex',
             hue_order=['Female','Male'],kind='reg',# 'scatter','kde','hist','reg'
             diag_kind='hist'
             )
plt.show()
# Out:
# c:\Users\Naincy\miniconda3\lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
tp1=tp.head(20)

# %%
sns.pairplot(tp1,hue='sex',
             hue_order=['Female','Male'],
             markers=['o','>']                
            )
plt.show()
# Out:
# c:\Users\Naincy\miniconda3\lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %% [markdown]
# # Strip plot

# %%
t=sns.load_dataset('tips')
t
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.stripplot(x='day',y='total_bill',data=t,hue='sex',
              linewidth=0.5,edgecolor='r',
              #jitter=2
              size=5,
              marker='<'
              )
plt.show()

# %%
sns.stripplot(x=t['total_bill']) #y=t['total_bill'] for vertical presentation
plt.show()

# %% [markdown]
# # Box Plot

# %%
ps=sns.load_dataset('tips')
ps
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.set(style='whitegrid')
sns.boxplot(x='day',y='total_bill',hue='sex',data=ps,color='g',
            order=['Fri','Sun','Thur','Sat'],
            showmeans=True
            )
plt.show()

# %%
sns.set(style='whitegrid')
sns.boxplot(x='day',y='total_bill',data=ps,color='r',
            order=['Fri','Sun','Thur','Sat'],
            showmeans=True
            )
plt.show()

# %%
sns.set(style='whitegrid')
sns.boxplot(x='day',y='total_bill',data=ps,color='r',
            order=['Fri','Sun','Thur','Sat'],
            showmeans=True,meanprops={'marker':'+','markeredgecolor':'w'},
            linewidth=2,palette='PuBuGn',orient='v' # to make horizontal give numerical data to x axis
            )
plt.show()

# %%
sns.set(style='whitegrid')
sns.boxplot(x='total_bill',y='day',data=ps,color='r', # to make horizontal give numerical data to x axis
            order=['Fri','Sun','Thur','Sat'],
            showmeans=True,meanprops={'marker':'+','markeredgecolor':'w'},
            linewidth=2,palette='PuBuGn'
            ) 
plt.show()

# %%
sns.set(style='whitegrid')
sns.boxplot(data=ps,
            showmeans=True,meanprops={'marker':'+','markeredgecolor':'w'},
            linewidth=2,palette='PuBuGn',orient='h'
            ) 
plt.show()

# %%
sns.set(style='whitegrid')
sns.boxplot(x=ps['total_bill'])
plt.show()

# %% [markdown]
# # Cat Plot

# %%
p=ps.head(20)
p
# Out:
#     total_bill   tip     sex smoker  day    time  size
# 0        16.99  1.01  Female     No  Sun  Dinner     2
# 1        10.34  1.66    Male     No  Sun  Dinner     3
# 2        21.01  3.50    Male     No  Sun  Dinner     3
# 3        23.68  3.31    Male     No  Sun  Dinner     2
# 4        24.59  3.61  Female     No  Sun  Dinner     4
# 5        25.29  4.71    Male     No  Sun  Dinner     4
# 6         8.77  2.00    Male     No  Sun  Dinner     2
# 7        26.88  3.12    Male     No  Sun  Dinner     4
# 8        15.04  1.96    Male     No  Sun  Dinner     2
# 9        14.78  3.23    Male     No  Sun  Dinner     2
# 10       10.27  1.71    Male     No  Sun  Dinner     2
# 11       35.26  5.00  Female     No  Sun  Dinner     4
# 12       15.42  1.57    Male     No  Sun  Dinner     2
# 13       18.43  3.00    Male     No  Sun  Dinner     4
# 14       14.83  3.02  Female     No  Sun  Dinner     2
# 15       21.58  3.92    Male     No  Sun  Dinner     2
# ...

# %%
sns.catplot(x='size',y='tip',data=p)
plt.show()
# Out:
# c:\Users\Naincy\miniconda3\lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %% [markdown]
# kind=' '
#
#  Categorical scatter plots with catplot
#    - stripplot()-with kind="strip"
#    - swarmplot()-with kind="swarm"
#
#  Categorical distribution plots with catplot
#    - boxplot()-with kind="box"
#    - violinplot()-with kind="violin"
#    - boxenplot()-with kind="boxen"
#
#  Categorical estimate plots with catplot
#    - pointplot()-with kind="point"
#    - barplot()-with kind="bar"
#    - countplot()-with kind="count"

# %%
sns.catplot(x='tip',y='size',data=p,hue='sex',
            palette='Oranges',height=10)
plt.show()
# Out:
# c:\Users\Naincy\miniconda3\lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.catplot(x='day',y='size',data=p,hue='sex',
            palette='Oranges',kind='boxen')
plt.show()
# Out:
# c:\Users\Naincy\miniconda3\lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %% [markdown]
# # seaborn figure style

# %%
sns.boxplot(y=ps["total_bill"])
plt.show()

# %%
sns.set(style='darkgrid') # style='dark', 'whitegrid'

sns.barplot(x='day',y="total_bill",data=ps)

plt.show()

# %%
sns.set(style='ticks') # no grid

sns.barplot(x='day',y="total_bill",data=ps)

plt.show()

# %%
sns.set(style='darkgrid') 

sns.barplot(x='day',y="total_bill",data=ps)

plt.grid()
plt.show()

# %% [markdown]
# # removing axes spines

# %%
sns.set(style='white') 

sns.barplot(x='day',y="total_bill",data=ps)

sns.despine()
plt.show()

# %%
sns.set(style='white') 

plt.figure(figsize=(6,5))

sns.barplot(x='day',y="total_bill",data=ps)

sns.despine()
plt.show()

# %%
sns.set(style='white') 

sns.set_context('paper',font_scale=0.8) # 'poster'

sns.barplot(x='day',y="total_bill",data=ps)

sns.despine()
plt.show()

# %%
sns.set(style='white') 

sns.barplot(x='day',y="total_bill",data=ps,palette='cool')

plt.show()
