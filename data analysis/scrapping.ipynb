# %%
from dputils.scrape import Tag, Scraper

# %% [markdown]
# - Tag class helps to decide what to collect from the page
# - scraper executes the scraping process

# %%
url= "https://www.amazon.in/s?k=laptop&crid=29R2J86BSUQE0&sprefix=laptop%2Caps%2C216&ref=nb_sb_noss_1"

# %%
amazon = Scraper(url)

# %%
target = Tag(cls = "s-main-slot s-result-list s-search-results sg-row")
items = Tag(cls="s-result-item")
title = Tag('h2',cls="a-size-mini a-spacing-none a-color-base s-line-clamp-2")
price = Tag('span',cls = "a-price")

# %%
result=amazon.get_all(target,items,heading=title,price=price)

# %%
import pandas as pd

# %%
df=pd.DataFrame(result)
df
# Out:
#                                               heading           price
# 0                                                None  ₹38,990₹38,990
# 1                                                None            None
# 2   Acer Aspire Lite 11th Gen Intel Core i5 Premiu...  ₹38,990₹38,990
# 3   HP Laptop 15s, 11th Gen Intel Core i3-1115G4, ...  ₹35,990₹35,990
# 4   Dell 15 Laptop, Intel Core i5-1135G7 Processor...  ₹46,990₹46,990
# 5                                                None            None
# 6   Acer Aspire Lite 11th Gen Intel Core i3 Premiu...  ₹27,990₹27,990
# 7   Dell 14 Laptop, Intel Core 11th Gen i3-1115G4/...  ₹34,990₹34,990
# 8   Dell 14 Laptop, Intel Core i5-1135G7 Processor...  ₹43,990₹43,990
# 9   ASUS TUF Gaming F15, 15.6"(39.62 cms) FHD 144H...  ₹69,990₹69,990
# 10  HP Laptop 15s, 12th Gen Intel Core i3-1215U, 1...  ₹38,990₹38,990
# 11  ASUS Vivobook Go 14 (2023), AMD Ryzen 3 7320U,...  ₹34,990₹34,990
# 12                                               None            None
# 13  HP Laptop 15s, 12th Gen Intel Core i7-1255U, 1...  ₹63,990₹63,990
# 14  MSI Modern 14, Intel 12th Gen. i7-1255U, 36CM ...  ₹49,990₹49,990
# 15  HP Laptop 15s, Intel Celeron, 15.6-inch (39.6 ...  ₹28,490₹28,490
# 16  Acer Aspire Lite 11th Gen Intel Core i3 Premiu...  ₹26,990₹26,990
# 17  ASUS Vivobook 15, IntelCore i7-12650H 12th Gen...  ₹59,990₹59,990
# 18  HP Laptop 15s, 11th Gen Intel Core i5-1155G7, ...  ₹54,160₹54,160
# 19  HONOR MagicBook X14 (2023), 12th Gen Intel Cor...  ₹48,990₹48,990
# 20                                               None            None
# 21                                               None            None
# 22                                               None            None
# 23                                               None            None
# 24                                               None            None
