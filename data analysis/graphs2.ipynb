# %%
import seaborn as sns 
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import plotly.express as px

# %%
titanic=sns.load_dataset('titanic')
titanic
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
print(titanic['survived'].unique())
print(titanic['pclass'].unique())
print(titanic['age'].unique())
# Out:
# [0 1]
# [3 1 2]
# [22.   38.   26.   35.     nan 54.    2.   27.   14.    4.   58.   20.
#  39.   55.   31.   34.   15.   28.    8.   19.   40.   66.   42.   21.
#  18.    3.    7.   49.   29.   65.   28.5   5.   11.   45.   17.   32.
#  16.   25.    0.83 30.   33.   23.   24.   46.   59.   71.   37.   47.
#  14.5  70.5  32.5  12.    9.   36.5  51.   55.5  40.5  44.    1.   61.
#  56.   50.   36.   45.5  20.5  62.   41.   52.   63.   23.5   0.92 43.
#  60.   10.   64.   13.   48.    0.75 53.   57.   80.   70.   24.5   6.
#   0.67 30.5   0.42 34.5  74.  ]

# %% [markdown]
# # categorical graphs
# - columns that have text are generally categorical
# - the first step is to count the number of unique values in column
# - then plot the count of each category
# - following charts are the good way to visualize categorical data
#      - bar chart
#      - pie chart
#      - donut chart
#      - line chart (when too many categories)
#      - area chart

# %%
print(titanic['survived'].value_counts())
# Out:
# survived
# 0    549
# 1    342
# Name: count, dtype: int64

# %%
survival_count=titanic['alive'].value_counts()
survival_count.plot(kind="pie", autopct="%.1f%%", title='survival rate ')
# Out:
# <Axes: title={'center': 'survival rate '}, ylabel='count'>

# %%
survival_count.plot(kind="pie", 
   autopct="%.1f%%", 
   title='survival rate',
   labels=['Survived','not survived'],
   colors=['#66b3ff','#ff9999'],
   labeldistance=1.1,
   wedgeprops={
       'width':0.5,
   })
# Out:
# <Axes: title={'center': 'survival rate'}, ylabel='count'>

# %%
layer=titanic['pclass'].value_counts()
layer.plot(kind='pie',autopct='%.2f%%',title='titanic layers')
# Out:
# <Axes: title={'center': 'titanic layers'}, ylabel='count'>

# %%
layer=titanic['pclass'].value_counts()
layer.plot(kind='bar',title='titanic layers')
# Out:
# <Axes: title={'center': 'titanic layers'}, xlabel='pclass'>

# %%
person=titanic['who'].value_counts()
person.plot(kind='pie',autopct='%.2f%%',title='person gender')
# Out:
# <Axes: title={'center': 'person gender'}, ylabel='count'>

# %% [markdown]
# # Seaborn
#   for complex data visualization using simple code

# %%
sns.countplot(data=titanic, x='alive')
# Out:
# <Axes: xlabel='alive', ylabel='count'>

# %%
sns.countplot(data=titanic, x='alive',hue='sex')
# Out:
# <Axes: xlabel='alive', ylabel='count'>

# %%
sns.jointplot(data=titanic, x='fare', y='age', kind='scatter', hue='survived',col=) #kind= 'hex'

# %%
#sns.catplot(data=titanic, x='fare', y='age', kind='scatter', hue='survived',col='pclass')

# %%
tip=sns.load_dataset("tips")
print(tip)
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.set_theme()
sns.relplot(data=tip, x='total_bill', y='tip', col='time', hue='smoker', style='smoker', size='size' )
# Out:
# c:\Users\Naincy\miniconda3\lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
