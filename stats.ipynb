# %% [markdown]
# # Statistical Implementation
# Measure of Central Tendency
#   1. Mean
#   2. Median
#   3. Mode

# %%
import numpy as np
import pandas as pd
import statistics as st

# %%
ages=[23,24,32,45,12,43,67,45,32,56,32,120]

# %%
print(np.mean(ages))
print(np.median(ages))
# Out:
# 44.25
# 37.5

# %%
print(st.mean(ages))
print(st.median(ages))
# Out:
# 44.25
# 37.5

# %%
st.mode(ages)
# Out:
# 32

# %% [markdown]
# # outlier

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
sns.boxplot(x=ages)
plt.show()

# %% [markdown]
# # 5 Number Summary

# %%
q1,q3=np.percentile(ages,[25,75])

# %%
print(q1)
print(q3)
# Out:
# 30.0
# 47.75

# %%
iqr=q3-q1
lwr_fence=q1-(1.5*iqr)
hir_fence=q3+(1.5*iqr)
print(lwr_fence,hir_fence)
# Out:
# 3.375 74.375

# %% [markdown]
# # Measure of Dispersion
#   1. Variance
#   2. Standard Deviation

# %%
st.variance(ages) # calculates sample variance
# Out:
# 795.2954545454545

# %%
np.var(ages) # calculates population variance
# Out:
# 729.0208333333334

# %%
# population variance 

def variance(age_data):
    n=len(age_data)
    m=np.mean(age_data)

    deviation=[(x-m)**2 for x in age_data]

    variance=sum(deviation) / n
    
    return variance

variance(ages)
# Out:
# 729.0208333333334

# %%
# sample variance
def variance(data):
    n=len(data)
    m=sum(data)/n   

    deviation=[(i-m)**2 for i in data]

    variance=sum(deviation) / (n-1)

    return variance

variance(ages)
# Out:
# 795.2954545454545

# %%
# variance using degree of freedom

def variance(data,dof=0): # 0 is by default in case no value is passed 
    n=len(data)
    m=np.mean(data)

    deviation= [(i-m)**2 for i in data]

    variance= sum(deviation) / (n-dof)

    return variance

variance(ages,1) # 0 for population variance , 1 for sample variance and other numbers for other variances
# Out:
# 795.2954545454545

# %%
# pvariance() is built-in function for population variance
st.pvariance(ages)
# Out:
# 729.0208333333334

# %%
# standard deviation for pvariance
import math
math.sqrt(st.pvariance(ages))
# Out:
# 27.000385799712813

# %% [markdown]
# # Histograms and PDF

# %%
sns.histplot(ages,kde=True) #pdf (probability density function)
plt.show()

# %%
df=sns.load_dataset('iris')
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
sns.histplot(df['sepal_length'],kde=True)
plt.show()

# %%
sns.histplot(df['sepal_width'],kde=True)
plt.show()

# %%
sns.histplot(df['petal_length'],kde=True)
plt.show()

# %%
# creating a normal distributed data
s=np.random.normal(0.5,0.2,1000)
s
# Out:
# array([ 0.64430926,  0.31219576,  0.59621527,  0.45200416,  0.70177896,
#         0.37815703,  0.35470641,  0.68418083,  0.6145585 ,  0.67646237,
#         0.67364874,  0.58256746,  0.65053087,  0.60193756,  0.57528705,
#         0.31543706,  0.41797605,  0.54080605,  0.51809227,  0.16867642,
#         0.39377309,  0.50934419,  0.45686894,  0.12191172,  0.4173273 ,
#         0.32558149,  0.93746997,  0.25335591,  0.43214033,  0.61878717,
#         0.59020666,  0.445031  ,  0.49655298,  0.04549789,  0.39832051,
#         0.3549019 ,  0.10825651,  0.51341978,  0.23708538,  0.31608148,
#         0.70994062,  0.5564389 ,  0.37221107,  0.40530768,  0.23308355,
#         0.69213434,  0.42186874,  0.52237571,  0.52618538,  0.49027718,
#         0.32605487,  0.88370105,  0.24891793,  0.53392599,  0.67527266,
#        -0.01909907,  0.42403102,  0.51512809,  0.27189783,  0.58275252,
#         0.41381554,  0.36025978,  0.44187032,  0.30554685,  0.99884437,
# ...

# %%
sns.histplot(s,kde=True)
plt.show()

# %% [markdown]
# # Log normal distribution
# Power Law Distribution

# %%
mu,sigma=3. ,1. # mean and standard deviation
s=np.random.lognormal(mu,sigma, 100)
sns.histplot(s,kde=True)
plt.show()

# %%
sns.histplot(np.log(s),kde=True)
plt.show()
